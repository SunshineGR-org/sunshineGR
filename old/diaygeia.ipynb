# %%
import opendata

# 
import importlib
importlib.reload(opendata)

c = opendata.OpendataClient()
c.get_advanced_search_results(q='decisionType:\"ΟΡΙΣΤΙΚΟΠΟΙΗΣΗ ΠΛΗΡΩΜΗΣ\"', page=0, size=10, issue_date_from="2022-01-01")
# x = c.get_decision_types()
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'diavgeia.gov.gr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'decisions': [{'ada': 'ΨΧΛ7ΟΡΡΘ-ΝΗΙ',
#    'protocolNumber': 'E22004529',
#    'issueDate': '01/11/2022 02:00:00',
#    'submissionTimestamp': '29/08/2022 14:30:50',
#    'publishTimestamp': '29/08/2022 14:30:50',
#    'status': 'PUBLISHED',
#    'documentUrl': 'https://diavgeia.gov.gr/doc/ΨΧΛ7ΟΡΡΘ-ΝΗΙ',
#    'subject': 'ΕΝΤΟΛΗ ΠΛΗΡΩΜΗΣ',
#    'documentType': 'ΠΡΑΞΗ',
#    'versionComment': None,
#    'decisionType': {'uid': 'Β.2.2', 'label': 'ΟΡΙΣΤΙΚΟΠΟΙΗΣΗ ΠΛΗΡΩΜΗΣ'},
#    'thematicCategories': [{'uid': '64',
#      'label': 'ΠΑΡΑΓΩΓΗ, ΤΕΧΝΟΛΟΓΙΑ ΚΑΙ ΕΡΕΥΝΑ'}],
#    'organization': {'uid': '50034',
#     'label': 'ΕΛΛΗΝΙΚΟ ΚΕΝΤΡΟ ΘΑΛΑΣΣΙΩΝ ΕΡΕΥΝΩΝ (ΕΛ.ΚΕ.Θ.Ε.)',
# ...

# %%
(10000000/200)*25/3600
(10000000/200)*200/(1024*1024)
# Out:
# 9.5367431640625

# %% [markdown]
# We have 10M decisions of type Οριστικοποιηση Πληρωμής. The max we can fetch in one go is 200. This gives us the following raw numbers

# %%
documents = 10000000
docs_per_page = 200
response_time__s  = 25
response_size__KB = 200
SECS_TO_HOUR = 3600
KB_TO_GB = 1024*1024
single_threaded_process_time = (documents/docs_per_page)*response_time__s/SECS_TO_HOUR
storage = (documents/docs_per_page)*response_size__KB/KB_TO_GB
print("Single-Threaded Proces Time : %d hours" % single_threaded_process_time)
print("Storage needed: %dGB" % storage)
# Out:
# Single-Threaded Proces Time : 347 hours
# Storage needed: 9GB

# %%
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'diavgeia.gov.gr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/jg/_37k4dj934n2lqmbwbt6mx340000gn/T/ipykernel_13672/2037215409.py in <module>
# ----> 1 c.get_simple_search_results(from_date='2022-11-01', to_date='2022-11-09')
#
# ~/dev/datagovgr/opendata.py in get_simple_search_results(self, **kwargs)
#     290         status: Accepted values are 'published', 'revoked',
#     291                'pending_revocation', and 'all'. Default: 'all'
# --> 292         page: Result page number. Default: 0
# ...
